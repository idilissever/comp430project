# %%
import pandas as pd

df = pd.read_csv("../../anjana_anonymizer/adult_over_simplified_anonymized/adult_k1.csv")

last_column = df.columns[-1]

distribution = df[last_column].value_counts(normalize=True) * 100

print(distribution.round(2).to_string())
# Out:
# income
# <=50K    75.1
# >50K     24.9

# %%
df = pd.read_csv("../../anjana_anonymizer/banking_simplified_anonymized/banking_k1.csv")

last_column = df.columns[-1]

distribution = df[last_column].value_counts(normalize=True) * 100

print(distribution.round(2).to_string())
# Out:
# y
# no     88.3
# yes    11.7
