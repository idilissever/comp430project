# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("classification_accuracy_report.csv")
df = df.sort_values(["model", "k"])
df
# Out:
#       k                model  train_accuracy  test_accuracy  precision  recall
# 0     2        Decision Tree          0.8767         0.7979     0.6074  0.4970
# 1     4        Decision Tree          0.8540         0.8036     0.6234  0.5061
# 2     8        Decision Tree          0.8402         0.8177     0.6713  0.5414
# 3    16        Decision Tree          0.8312         0.8100     0.6567  0.5083
# 4    32        Decision Tree          0.8251         0.8167     0.6695  0.5197
# 5    64        Decision Tree          0.8155         0.8192     0.6829  0.4719
# 6   128        Decision Tree          0.8093         0.8162     0.6584  0.4931
# 7     2  Logistic Regression          0.7940         0.8094     0.6893  0.4050
# 8     4  Logistic Regression          0.7954         0.7920     0.6238  0.3860
# 9     8  Logistic Regression          0.7952         0.7941     0.6548  0.3868
# 10   16  Logistic Regression          0.7894         0.7862     0.6168  0.3893
# ...

# %%
df
# Out:
#       k                model  train_accuracy  test_accuracy  precision  recall
# 0     2        Decision Tree          0.8767         0.7979     0.6074  0.4970
# 1     4        Decision Tree          0.8540         0.8036     0.6234  0.5061
# 2     8        Decision Tree          0.8402         0.8177     0.6713  0.5414
# 3    16        Decision Tree          0.8312         0.8100     0.6567  0.5083
# 4    32        Decision Tree          0.8251         0.8167     0.6695  0.5197
# 5    64        Decision Tree          0.8155         0.8192     0.6829  0.4719
# 6   128        Decision Tree          0.8093         0.8162     0.6584  0.4931
# 7     2  Logistic Regression          0.7940         0.8094     0.6893  0.4050
# 8     4  Logistic Regression          0.7954         0.7920     0.6238  0.3860
# 9     8  Logistic Regression          0.7952         0.7941     0.6548  0.3868
# 10   16  Logistic Regression          0.7894         0.7862     0.6168  0.3893
# ...
